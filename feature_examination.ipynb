# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data/train.csv")
df_test = pd.read_csv("Data/test.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.groupby(['Age'])['Survived'].mean()
# Out:
# Age
# 0.42     1.0
# 0.67     1.0
# 0.75     1.0
# 0.83     1.0
# 0.92     1.0
#         ...
# 70.00    0.0
# 70.50    0.0
# 71.00    0.0
# 74.00    0.0
# 80.00    1.0
# Name: Survived, Length: 88, dtype: float64

# %%
titanic_df = df.dropna(subset=['Age', 'Survived'])
dizi = np.arange(0, 101, 15)
arr= [0,18,25,45,65,100]

titanic_df['age_category'] = pd.cut(titanic_df['Age'], bins=dizi)

# Her yaş kategorisi için hayatta kalma oranını hesaplayalım
survival_rates = titanic_df.groupby('age_category')['Survived'].mean()

# Grafiği çizelim
plt.figure(figsize=(15, 6))
sns.barplot(x=survival_rates.index, y=survival_rates.values)
plt.title('Hayatta Kalma Oranı Yaş Kategorisine Göre')
plt.xlabel('Yaş Kategorisi')
plt.ylabel('Hayatta Kalma Oranı')
plt.show()
# Out:
# C:\Users\bgraslan\AppData\Local\Temp\ipykernel_8492\2072406374.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_df['age_category'] = pd.cut(titanic_df['Age'], bins=dizi)
# C:\Users\bgraslan\AppData\Local\Temp\ipykernel_8492\2072406374.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_rates = titanic_df.groupby('age_category')['Survived'].mean()
# C:\Users\bgraslan\Desktop\Conda\Kaggle_Comps\env\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
titanic= df.dropna(subset=['Age', 'Survived'])
dizi = np.arange(0, 101, 15)
arr= [0,5,12,20,30,50,100]

titanic['age_category'] = pd.cut(titanic['Age'], bins=arr)

titanic['age_category'].value_counts()
# Out:
# C:\Users\bgraslan\AppData\Local\Temp\ipykernel_8492\3839369972.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['age_category'] = pd.cut(titanic['Age'], bins=arr)
# age_category
# (30, 50]     241
# (20, 30]     230
# (12, 20]     110
# (50, 100]     64
# (0, 5]        44
# (5, 12]       25
# Name: count, dtype: int64

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked age_category
# 0        0         A/5 21171   7.2500   NaN        S     (21, 22]
# 1        0          PC 17599  71.2833   C85        C     (37, 38]
# 2        0  STON/O2. 3101282   7.9250   NaN        S     (25, 26]
# 3        0            113803  53.1000  C123        S     (34, 35]
# 4        0            373450   8.0500   NaN        S     (34, 35]
# ..     ...               ...      ...   ...      ...          ...
# 885      5            382652  29.1250   NaN        Q     (38, 39]
# 886      0            211536  13.0000   NaN        S     (26, 27]
# 887      0            112053  30.0000   B42        S     (18, 19]
# 889      0            111369  30.0000  C148        C     (25, 26]
# 890      0            370376   7.7500   NaN        Q     (31, 32]
#
# [714 rows x 13 columns]

# %%
Passangers =  ['Mrs', 'Mr', 'Miss', 'Ms', 'Mme', 'Mlle', 'Master']
Royals = ['Lady', 'Sir', 'Don', 'Jonkheer', 'Countess', 'Dona']
Crews = ['Major', 'Col', 'Rev', 'Capt', 'Dr']

df['Title'] = df['Name'].apply(lambda x: x.split('.')[0].split()[-1])
df_test['Title'] = df_test['Name'].apply(lambda x: x.split('.')[0].split()[-1])

df['Status']= df['Title'].apply(lambda x: 'Passanger' if x in Passangers  else ('Royale' if x in Royals else ('Crew' if x in Crews else 'Missing')))
df_test['Status']= df_test['Title'].apply(lambda x: 'Passanger' if x in Passangers  else ('Royale' if x in Royals else ('Crew' if x in Crews else 'Missing')))

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Title     Status
# 0        0         A/5 21171   7.2500   NaN        S    Mr  Passanger
# 1        0          PC 17599  71.2833   C85        C   Mrs  Passanger
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Passanger
# 3        0            113803  53.1000  C123        S   Mrs  Passanger
# 4        0            373450   8.0500   NaN        S    Mr  Passanger
# ..     ...               ...      ...   ...      ...   ...        ...
# 886      0            211536  13.0000   NaN        S   Rev       Crew
# 887      0            112053  30.0000   B42        S  Miss  Passanger
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Passanger
# 889      0            111369  30.0000  C148        C    Mr  Passanger
# 890      0            370376   7.7500   NaN        Q    Mr  Passanger
#
# [891 rows x 14 columns]

# %%
for label, content in df.items():
    if not pd.api.types.is_numeric_dtype(content):
        df[label] = content.astype("category").cat.as_ordered()

for label, content in df_test.items():
    if not pd.api.types.is_numeric_dtype(content):
        df_test[label] = content.astype("category").cat.as_ordered()

# %%
x=df.groupby(['Pclass','Sex']).Survived.mean()
x
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: Survived, dtype: float64

# %%
x=df.groupby(['Status']).Survived.mean()
x
# Out:
# C:\Users\bgraslan\AppData\Local\Temp\ipykernel_12560\763201463.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   x=df.groupby(['Status']).Survived.mean()
# Status
# Crew         0.277778
# Passanger    0.384793
# Royale       0.600000
# Name: Survived, dtype: float64

# %%
x=df.groupby(['SibSp']).Survived.mean()
x
# Out:
# SibSp
# 0    0.345395
# 1    0.535885
# 2    0.464286
# 3    0.250000
# 4    0.166667
# 5    0.000000
# 8    0.000000
# Name: Survived, dtype: float64

# %%
x=df.groupby(['Parch']).Survived.mean()
x
# Out:
# Parch
# 0    0.343658
# 1    0.550847
# 2    0.500000
# 3    0.600000
# 4    0.000000
# 5    0.200000
# 6    0.000000
# Name: Survived, dtype: float64

# %%
df['Family']=df['Parch']+df['SibSp']+1
df_test['Family']=df_test['Parch']+df_test['SibSp']+1

x=df.groupby('Family').Survived.mean()

"""df['Family'] = pd.cut(df['Family'], bins=[0,1,4,8,15])
df_test['Family'] = pd.cut(df_test['Family'], bins=[0,1,4,8,15])"""
# Out:
# "df['Family'] = pd.cut(df['Family'], bins=[0,1,4,8,15])\ndf_test['Family'] = pd.cut(df_test['Family'], bins=[0,1,4,8,15])"

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Family
# 0           0       3    1  22.0      1      0   7.2500         2       2
# 1           1       1    0  38.0      1      0  71.2833         0       2
# 2           1       3    0  26.0      0      0   7.9250         2       1
# 3           1       1    0  35.0      1      0  53.1000         2       2
# 4           0       3    1  35.0      0      0   8.0500         2       1
# ..        ...     ...  ...   ...    ...    ...      ...       ...     ...
# 886         0       2    1  27.0      0      0  13.0000         2       1
# 887         1       1    0  19.0      0      0  30.0000         2       1
# 888         0       3    0  24.0      1      2  23.4500         2       4
# 889         1       1    1  26.0      0      0  30.0000         0       1
# 890         0       3    1  32.0      0      0   7.7500         1       1
#
# [891 rows x 9 columns]

# %%
df['Embarked'].value_counts()/df.shape[0]
# Out:
# Embarked
# S    0.722783
# C    0.188552
# Q    0.086420
# Name: count, dtype: float64

# %%
df_test['Embarked'].value_counts()/df_test.shape[0]
# Out:
# Embarked
# S    0.645933
# C    0.244019
# Q    0.110048
# Name: count, dtype: float64

# %%
df.shape
# Out:
# (891, 12)

# %%
x=df.groupby(['Pclass']).Sex.value_counts()/df.shape[0]
x_test=df_test.groupby(['Pclass']).Sex.value_counts()/df_test.shape[0]

# %%
x
# Out:
# Pclass  Sex
# 1       male      0.136925
#         female    0.105499
# 2       male      0.121212
#         female    0.085297
# 3       male      0.389450
#         female    0.161616
# Name: count, dtype: float64

# %%
x_test
# Out:
# Pclass  Sex
# 1       male      0.136364
#         female    0.119617
# 2       male      0.150718
#         female    0.071770
# 3       male      0.349282
#         female    0.172249
# Name: count, dtype: float64

# %%
df['Parch'].mean()
# Out:
# 0.38159371492704824

# %%
df_test['Parch'].mean()
# Out:
# 0.3923444976076555

# %%
df['Family'].value_counts()/df.shape[0]
# Out:
# Family
# (0, 1]     0.602694
# (1, 4]     0.327722
# (4, 8]     0.061728
# (8, 15]    0.007856
# Name: count, dtype: float64

# %%
df_test['Family'].value_counts()/df_test.shape[0]
# Out:
# Family
# (0, 1]     0.605263
# (1, 4]     0.346890
# (4, 8]     0.038278
# (8, 15]    0.009569
# Name: count, dtype: float64

# %%
df.drop(columns=['PassengerId','Name','Ticket','Cabin'], inplace=True)
df_test.drop(columns=['PassengerId','Name','Ticket','Cabin'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df['Embarked'].fillna('S', inplace=True)
df_test['Fare'].fillna(26.55, inplace=True)
for i,r in df.iterrows():
    if pd.isnull(r['Age']):
        df.loc[df.index[i],'Age'] = df[df['Pclass'] == r['Pclass']]['Age'].median()

for i,r in df_test.iterrows():
    if pd.isnull(r['Age']):
        df_test.loc[df_test.index[i],'Age'] = df_test[df_test['Pclass'] == r['Pclass']]['Age'].median()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
for label, content in df.items():
    if not pd.api.types.is_numeric_dtype(content):
        df[label] = content.astype("category").cat.as_ordered()

for label, content in df_test.items():
    if not pd.api.types.is_numeric_dtype(content):
        df_test[label] = content.astype("category").cat.as_ordered()

for label, content in df.items():
    if not pd.api.types.is_numeric_dtype(content):
            df[label] = pd.Categorical(content).codes

for label, content in df_test.items():
    if not pd.api.types.is_numeric_dtype(content):
            df_test[label] = pd.Categorical(content).codes

# %%
correlation_matrix = df.corr()

# %%
arr=[0,5,12,20,30,50,100]
df['Age'] = pd.cut(df['Age'], bins=arr)
df_test['Age'] = pd.cut(df_test['Age'], bins=arr)

# %%
correlation_matrix
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481 -0.543351 -0.047255 -0.035322  0.081629
# Pclass   -0.338481  1.000000  0.131900 -0.408487  0.083081  0.018443
# Sex      -0.543351  0.131900  1.000000  0.078421 -0.114631 -0.245489
# Age      -0.047255 -0.408487  0.078421  1.000000 -0.243526 -0.171095
# SibSp    -0.035322  0.083081 -0.114631 -0.243526  1.000000  0.414838
# Parch     0.081629  0.018443 -0.245489 -0.171095  0.414838  1.000000
# Fare      0.257307 -0.549500 -0.182333  0.123784  0.159651  0.216225
# Embarked -0.167675  0.162098  0.108262 -0.011245  0.068230  0.039798
#
#               Fare  Embarked
# Survived  0.257307 -0.167675
# Pclass   -0.549500  0.162098
# Sex      -0.182333  0.108262
# Age       0.123784 -0.011245
# SibSp     0.159651  0.068230
# Parch     0.216225  0.039798
# Fare      1.000000 -0.224719
# Embarked -0.224719  1.000000

# %%
correlation_matrix_t = df_test.corr()
correlation_matrix_t
# Out:
#             Pclass       Sex       Age     SibSp     Parch      Fare  Embarked
# Pclass    1.000000  0.108615 -0.529560  0.001087  0.018721 -0.576941  0.227983
# Sex       0.108615  1.000000 -0.005504 -0.099943 -0.159120 -0.191671  0.076281
# Age      -0.529560 -0.005504  1.000000 -0.078599 -0.054653  0.348892 -0.132330
# SibSp     0.001087 -0.099943 -0.078599  1.000000  0.306895  0.171677  0.052708
# Parch     0.018721 -0.159120 -0.054653  0.306895  1.000000  0.230150  0.054577
# Fare     -0.576941 -0.191671  0.348892  0.171677  0.230150  1.000000 -0.257296
# Embarked  0.227983  0.076281 -0.132330  0.052708  0.054577 -0.257296  1.000000

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.0      1      0   7.2500         2
# 1           1       1    0  38.0      1      0  71.2833         0
# 2           1       3    0  26.0      0      0   7.9250         2
# 3           1       1    0  35.0      1      0  53.1000         2
# 4           0       3    1  35.0      0      0   8.0500         2
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    1  27.0      0      0  13.0000         2
# 887         1       1    0  19.0      0      0  30.0000         2
# 888         0       3    0  24.0      1      2  23.4500         2
# 889         1       1    1  26.0      0      0  30.0000         0
# 890         0       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 8 columns]

# %%
df['Sex']=df['Sex']*4 + 1

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481 -0.543351 -0.047255 -0.035322  0.081629
# Pclass   -0.338481  1.000000  0.131900 -0.408487  0.083081  0.018443
# Sex      -0.543351  0.131900  1.000000  0.078421 -0.114631 -0.245489
# Age      -0.047255 -0.408487  0.078421  1.000000 -0.243526 -0.171095
# SibSp    -0.035322  0.083081 -0.114631 -0.243526  1.000000  0.414838
# Parch     0.081629  0.018443 -0.245489 -0.171095  0.414838  1.000000
# Fare      0.257307 -0.549500 -0.182333  0.123784  0.159651  0.216225
# Embarked -0.167675  0.162098  0.108262 -0.011245  0.068230  0.039798
# m        -0.547689  0.608450  0.816273 -0.156656 -0.052027 -0.201760
#
#               Fare  Embarked         m
# Survived  0.257307 -0.167675 -0.547689
# Pclass   -0.549500  0.162098  0.608450
# Sex      -0.182333  0.108262  0.816273
# Age       0.123784 -0.011245 -0.156656
# SibSp     0.159651  0.068230 -0.052027
# Parch     0.216225  0.039798 -0.201760
# Fare      1.000000 -0.224719 -0.376131
# Embarked -0.224719  1.000000  0.159528
# m        -0.376131  0.159528  1.000000

# %%
df['m']=df['Pclass']*(df['Sex'])

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked   m
# 0           0       3    5  22.0      1      0   7.2500         2  15
# 1           1       1    1  38.0      1      0  71.2833         0   1
# 2           1       3    1  26.0      0      0   7.9250         2   3
# 3           1       1    1  35.0      1      0  53.1000         2   1
# 4           0       3    5  35.0      0      0   8.0500         2  15
# ..        ...     ...  ...   ...    ...    ...      ...       ...  ..
# 886         0       2    5  27.0      0      0  13.0000         2  10
# 887         1       1    1  19.0      0      0  30.0000         2   1
# 888         0       3    1  24.0      1      2  23.4500         2   3
# 889         1       1    5  26.0      0      0  30.0000         0   5
# 890         0       3    5  32.0      0      0   7.7500         1  15
#
# [891 rows x 9 columns]

# %%
df['Sex']=df['Sex']//3
